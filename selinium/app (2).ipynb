# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     280             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     281         )
# --> 282       raise ValueError('mount failed' + extra_reason)
#     283     elif case == 4:
#     284       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
# !pip install --quiet autokeras
# !pip install --quiet apify_client
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.7/122.7 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 30.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 78.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 75.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 75.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 51.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.4 MB/s eta 0:00:00

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 2.862s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 1 moderate severity vulnerability
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 34.16.173.209

# %%
! streamlit run /content/drive/MyDrive/PFA_all_files/streamlit/index.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.173.209:8501
#
# npx: installed 22 in 3.442s
# your url is: https://brown-sites-pump.loca.lt
# 2024-06-06 21:51:15.963984: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-06 21:51:17.695984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# sofia.sapiens
# nH2AHrwxeTRJoN5hX
# dSCLg0C3YEZ83HzYX
# post data
#                                    inputUrl  ...                 timestamp
# 0   https://www.instagram.com/sofia.sapiens  ...  2024-04-29T23:00:31.000Z
# 1   https://www.instagram.com/sofia.sapiens  ...  2022-11-09T21:08:40.000Z
# 2   https://www.instagram.com/sofia.sapiens  ...  2023-01-23T22:23:58.000Z
# 3   https://www.instagram.com/sofia.sapiens  ...  2024-05-28T20:02:41.000Z
# 4   https://www.instagram.com/sofia.sapiens  ...  2024-05-30T19:48:01.000Z
# ..                                      ...  ...                       ...
# 95  https://www.instagram.com/sofia.sapiens  ...  2023-09-19T19:57:50.000Z
# 96  https://www.instagram.com/sofia.sapiens  ...  2023-07-25T14:33:53.000Z
# 97  https://www.instagram.com/sofia.sapiens  ...  2023-07-28T00:31:00.000Z
# 98  https://www.instagram.com/sofia.sapiens  ...  2023-07-18T13:53:36.000Z
# 99  https://www.instagram.com/sofia.sapiens  ...  2023-07-24T12:30:00.000Z
#
# [100 rows x 4 columns]
# profile data
#                                   inputUrl  ... postsCount
# 0  https://www.instagram.com/sofia.sapiens  ...        330
#
# [1 rows x 6 columns]
# 100% 100/100 [00:30<00:00,  3.31it/s]
#                                    inputUrl  ...  image id
# 0   https://www.instagram.com/sofia.sapiens  ...  6a0ff5dd
# 1   https://www.instagram.com/sofia.sapiens  ...  a8a9c372
# 2   https://www.instagram.com/sofia.sapiens  ...  fae49534
# 3   https://www.instagram.com/sofia.sapiens  ...  2de3e841
# 4   https://www.instagram.com/sofia.sapiens  ...  281ac526
# ..                                      ...  ...       ...
# 95  https://www.instagram.com/sofia.sapiens  ...  6155b163
# 96  https://www.instagram.com/sofia.sapiens  ...  ba5f873c
# 97  https://www.instagram.com/sofia.sapiens  ...  9d18ca19
# 98  https://www.instagram.com/sofia.sapiens  ...  c3d3d147
# 99  https://www.instagram.com/sofia.sapiens  ...  a63be89d
#
# [100 rows x 10 columns]
# scrape done ----------------------------------
# data after processing    postsCount  followersCount  followsCount  ...  duration  frequency  avg_emojis
# 0   -0.508229       -0.165796     -0.572076  ... -0.618382  -0.538494    0.313696
#
# [1 rows x 9 columns]
# process done -------    postsCount  followersCount  followsCount  ...  duration  frequency  avg_emojis
# 0   -0.508229       -0.165796     -0.572076  ... -0.618382  -0.538494    0.313696
#
# [1 rows x 9 columns]
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 38 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# {'Openness': 0, 'Conscientiousness': 1, 'Extraversion': 0, 'Agreeableness': 1, 'Neuroticism': 0} {'Openness': 54.12916541099548, 'Conscientiousness': 79.59759831428528, 'Extraversion': 50.52834749221802, 'Agreeableness': 85.42050123214722, 'Neuroticism': 18.635909259319305}
# prediction done ------- ({'Openness': 0, 'Conscientiousness': 1, 'Extraversion': 0, 'Agreeableness': 1, 'Neuroticism': 0}, {'Openness': 54.12916541099548, 'Conscientiousness': 79.59759831428528, 'Extraversion': 50.52834749221802, 'Agreeableness': 85.42050123214722, 'Neuroticism': 18.635909259319305})

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.192s
# your url is: https://eleven-emus-sell.loca.lt
# ^C
